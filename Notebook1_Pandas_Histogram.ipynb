# %% [markdown]
# # Visualizing Data with Matplotlib

# %% [markdown]
# Let's first import some packages into our environment. Note that `%matplotlib inline` is an `IPython` magic command, which is not a part of standard Python syntax. Here `%matplotlib inline` enables the inline display of matplotlib figures so you don't need to do `plt.show()`.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# This is another `IPython` magic command that enables we to run bash commands in this environment. Let's first clone the "Motor Trend Car Road Tests" dataset. Note that the storage provided by Colab is not permanent (unless we [mount our Google Drive](https://colab.research.google.com/notebooks/io.ipynb)) so we need to be careful. If you would like to do your homework in this environment, please remember to save your work (like plotted figures) locally.

# %%
![ ! -f "./mtcars/mtcars.csv" ] && git clone https://gist.github.com/a412dfbd88b3db70b74b.git mtcars
# Out:
# Cloning into 'mtcars'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), done.

# %% [markdown]
# Now let's import the `mtcars` dataset. It's in standard CSV format with header so we can import directly. Sometimes data may be separated with tabs (or even worse a mixture of tabs and spaces) so we might need to designate a separator. Please refer to [this document](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) if you need more information.

# %%
cars = pd.read_csv('./mtcars/mtcars.csv')

# %%
cars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
num_cylinders = cars['cyl'].value_counts()
num_cylinders
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
plt.bar(num_cylinders.keys(), num_cylinders, color=['black',  'blue', 'orange'])
plt.title('Count of cars by Cylinder')
plt.xlabel('Num. of Cylinder')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
![ ! -f "./iris/iris.data" ] && mkdir ./iris/ && wget "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" -O ./iris/iris.data
# Out:
# --2020-08-09 14:54:13--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [application/x-httpd-php]
# Saving to: ‘./iris/iris.data’
#
# ./iris/iris.data    100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2020-08-09 14:54:13 (217 MB/s) - ‘./iris/iris.data’ saved [4551/4551]

# %% [markdown]
# This dataset doesn't include the attribute names in its header so we need to specify them manually, or the first line of the file will be regarded as the header.

# %%
iris = pd.read_csv('./iris/iris.data', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 90            5.5          2.6           4.4          1.2  Iris-versicolor
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 88            5.6          3.0           4.1          1.3  Iris-versicolor
# 95            5.7          3.0           4.2          1.2  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 27            5.2          3.5           1.5          0.2      Iris-setosa
# 106           4.9          2.5           4.5          1.7   Iris-virginica
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 86            6.7          3.1           4.7          1.5  Iris-versicolor
# 43            5.0          3.5           1.6          0.6      Iris-setosa

# %%
plt.subplot(1, 2, 1)
plt.hist(iris['sepal_length'], bins=50)
plt.xlabel('Sepal Length')
plt.ylabel('Count')
plt.title('Histogram of Sepal length with 50 bins')
plt.subplots_adjust(bottom=0, top=1, left=-0.5, right=1.5)
plt.subplot(1, 2, 2)
plt.hist(iris['sepal_length'], bins=20)
plt.xlabel('Sepal Length')
plt.ylabel('Count')
plt.title('Histogram of Sepal length with 20 bins')
plt.subplots_adjust(bottom=0, top=1, left=-0.5, right=1.5)

# %%
n_bins = 20

setosa = iris[iris['class'] == 'Iris-setosa']
versicolor = iris[iris['class'] == 'Iris-versicolor']
virginica = iris[iris['class'] == 'Iris-virginica']


colors = ['orange', 'blue', 'black']
labels = ['setosa','versicolor','virginica']
x_multi = [setosa['sepal_length'],versicolor['sepal_length'],virginica['sepal_length']]
plt.hist(x_multi, n_bins, histtype='bar',color=colors,label= labels)
plt.legend(prop={'size': 10})
plt.xlabel('Sepal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import pandas as pd
from pandas import DataFrame as df
data = pd.read_csv('data.txt',sep='\t',header=None)
data = df(data)

# %%
import matplotlib.pyplot as plt
date = data[2]
mwatt = data[1]
cost = data[0]

print(df.mean(data))

cost_mean = df.mean(data)[0]
mwatt_mean = df.mean(data)[1]
date_mean = df.mean(data)[2]

cost_Std = df.std(data)[0]
mwatt_Std = df.std(data)[1]
date_Std = df.std(data)[2]

cost_per_mwatt = pd.Series(cost / mwatt)
cost_per_mwatt_mean = cost_per_mwatt.mean()
cost_per_mwatt_Std = cost_per_mwatt.std()

print(cost_per_mwatt_mean)
print(cost_per_mwatt_Std)


# print(cost_mean)
# print(cost_Std)

# print(mwatt_mean)
# print(mwatt_Std)

# print(date_mean)
# print(date_Std)


plt.scatter(date, mwatt)
plt.show()

plt.scatter(date, cost)
plt.show()

plt.hist(cost_per_mwatt, bins=10)
plt.show()
# Out:
# 0    461.560313
# 1    825.375000
# 2     68.581250
# dtype: float64
# 0.569735439641486
# 0.1871243018960576

# %%
data = pd.read_csv('hotdog.txt',sep=' ',names=["Type", "Sodium", "Calories"])
data = df(data)

# %%
data = pd.read_csv('hotdog.txt',sep=' ',names=["Type", "Sodium", "Calories"])
data = df(data)

beef_calories = []
beef_sodium = []
poultry_calories = []
poultry_sodium = []
meat_calories = []
meat_sodium = []


for _, row in data.iterrows():
    if row["Type"] == "Beef":
        beef_sodium.append(row["Sodium"])
        beef_calories.append(row["Calories"])
    elif row["Type"] == "Meat":
        meat_sodium.append(row["Sodium"])
        meat_calories.append(row["Calories"])
    elif row["Type"] == "Poultry":
        poultry_sodium.append(row["Sodium"])
        poultry_calories.append(row["Calories"])

print(beef_calories)
print(beef_sodium)

import matplotlib.pyplot as plt

plt.hist(beef_sodium, bins=8, alpha=0.5, label="Beef")
plt.hist(meat_sodium, bins=8, alpha=0.5, label="Meat")
plt.hist(poultry_sodium, bins=8, alpha=0.5, label="Poultry")

plt.xlabel("Sodium")
plt.ylabel("Frequency")
plt.title("Class-Conditional Sodium Histogram")
plt.legend()
plt.show()

plt.hist(beef_calories, bins=8, alpha=0.5, label="Beef")
plt.hist(meat_calories, bins=8, alpha=0.5, label="Meat")
plt.hist(poultry_calories, bins=8, alpha=0.5, label="Poultry")

plt.xlabel("Calories")
plt.ylabel("Frequency")
plt.title("Class-Conditional Calories Histogram")
plt.legend()
plt.show()
# Out:
# [495, 477, 425, 322, 482, 587, 370, 322, 479, 375, 330, 300, 386, 401, 645, 440, 317, 319, 298, 253]
# [186, 181, 176, 149, 184, 190, 158, 139, 175, 148, 152, 111, 141, 153, 190, 157, 131, 149, 135, 132]

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Readability.csv")

# loading in the values for 3syl, sentences, and groups into lists
three_syl_values = df["3SYL"].tolist()
sentence_values = df["SEN"].tolist()
group_values = df["GROUP"].tolist()

group_1_syl_values = []
group_2_syl_values = []
group_3_syl_values = []
group_1_sen_values = []
group_2_sen_values = []
group_3_sen_values = []

for i in range(len(group_values)):
    if group_values[i] == 1:
        group_1_syl_values.append(three_syl_values[i])
        group_1_sen_values.append(sentence_values[i])
    elif group_values[i] == 2:
        group_2_syl_values.append(three_syl_values[i])
        group_2_sen_values.append(sentence_values[i])
    elif group_values[i] == 3:
        group_3_syl_values.append(three_syl_values[i])
        group_3_sen_values.append(sentence_values[i])

data = {'Group 1': group_1_syl_values, 'Group 2': group_2_syl_values, 'Group 3': group_3_syl_values}
sen_data = {'Group 1': group_1_sen_values, 'Group 2': group_2_sen_values, 'Group 3': group_3_sen_values}

plt.boxplot(data.values(), labels=data.keys(), vert=False)
plt.xlabel("# of 3+ Syllable Words")
plt.title("Boxplot of # of 3+ Syllable Words in Magazines by Group")
plt.show()

plt.boxplot(sen_data.values(), labels=sen_data.keys(), vert=False)
plt.xlabel("# of Sentences")
plt.title("Boxplot of # of Sentences in Magazines by Group")
plt.show()
# Out:
# /tmp/ipython-input-4149490316.py:33: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data.values(), labels=data.keys(), vert=False)
# /tmp/ipython-input-4149490316.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(sen_data.values(), labels=sen_data.keys(), vert=False)
